# %% [markdown]
# # Phase 1: Environment Setup & Accelerator Verification
#
# This notebook verifies the active PyTorch environment, checks for CUDA GPU device acceleration, configures project paths, and sets global random seeds to ensure training reproducibility.

# %%
# Install dependencies using Jupyter magic (bypasses Windows security policies)
# %pip install -q ultralytics scikit-learn seaborn matplotlib pyyaml grad-cam tensorboard
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Initialize Path resolution
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT.name != 'ai' and PROJECT_ROOT.parent != PROJECT_ROOT:
    if (PROJECT_ROOT / 'ai').exists():
        PROJECT_ROOT = PROJECT_ROOT / 'ai'
        break
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import utils
print("✅ Reusable AI utils successfully loaded from:", utils.paths.PROJECT_ROOT)
# Out:
# ✅ Reusable AI utils successfully loaded from: O:\Hackthons\KrishiOS\ai

# %%
# Verify acceleration hardware
utils.device.print_device_info()
device = utils.device.get_device()
# Out:
# PyTorch Version: 2.11.0+cu128
# CUDA Available : True
# Active GPU Name: NVIDIA GeForce RTX 4050 Laptop GPU

# %%
# Pin random seeds globally
utils.seed.set_seed(42)
# Out:
# 🔒 Random seed pinned globally to: 42
